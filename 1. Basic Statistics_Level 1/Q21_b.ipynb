# %%
import pandas as pd
import matplotlib.pyplot as plt
wc_at = pd.read_csv("wc-at.csv")
wc_at
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
plt.hist(wc_at["AT"])
# Out:
# (array([14., 18., 16., 13., 17., 14.,  4.,  6.,  3.,  4.]),
#  array([ 11.44 ,  35.596,  59.752,  83.908, 108.064, 132.22 , 156.376,
#         180.532, 204.688, 228.844, 253.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(wc_at["AT"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1aaadef0280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1aaadef0820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1aaadef00a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1aaadef0dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1aaadf000d0>],
#  'means': []}

# %%
plt.hist(wc_at["Waist"])
# Out:
# (array([ 2.,  9., 19., 17., 11.,  9., 13., 21.,  5.,  3.]),
#  array([ 63.5 ,  69.25,  75.  ,  80.75,  86.5 ,  92.25,  98.  , 103.75,
#         109.5 , 115.25, 121.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(wc_at["Waist"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1aab1096a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1aab10a6070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1aab10967c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1aab10a6610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1aab10a68e0>],
#  'means': []}

# %% [markdown]
# From the above histogram and box plot for both AT & Waist of wc-at data set, it shows that both AT & Waist follows normal distribution.
